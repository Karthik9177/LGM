# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\karthik\appdata\roaming\python\python39\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\karthik\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('mahal.jpg')
image1 = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image1))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
gray_image = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=250.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=275x183>
